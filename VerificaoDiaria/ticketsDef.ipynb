# %%
import pyautogui as pa
import time

# %%
entries = [
    {
        "client": "sinnc s",
        "tempo": "0030",
        "assunto": ">Cliente.: Sinnc >Tela.: Geral >Atividade.: Teste - Impressao",
        "descricao": """Bom Dia,
Realizados os testes de Impressao dos links.
Atenciosamente/Best Regards
"""
    },
    {
        "client": "sinnc s",
        "tempo": "0030",
        "assunto": ">Cliente.: Sinnc >Tela.: Geral >Atividade.: Verificacao - Senhas",
        "descricao": """Bom Dia,
Realizado Verificacao de links - Solicitacao de contra senha.
Atenciosamente/Best Regards
"""
    },
    {
        "client": "sinnc s",
        "tempo": "0030",
        "assunto": ">Cliente.: Sinnc >Tela.: Geral >Atividade.: Verificacao - cadSUS",
        "descricao": """Bom Dia,
Realizado as Verificacao de Consultas dos Cadsus.
Atenciosamente/Best Regards
"""
    },
    {
        "client": "Iju",
        "tempo": "0130",
        "assunto": ">Cliente.: Ijui >Tela.: Exportação e-SUS AB Atencao Basica >Atividade: Correcao das Inconsistencias",
        "descricao": """Boa Tarde,
Informamos que o processo de correcao das inconsistencias do e-SUS for realizado com sucesso. Agradecemos a todos os envolvidos pela colaboracao e empenho durante esse periodo.
Atenciosamente/Best Regards
"""
    },
    {
        "client": "Chapec",
        "tempo": "0130",
        "assunto": ">Cliente.: Chapeco >Tela.: Exportacao e-SUS AB Atencao Basica >Atividade: Correcao das Inconsistencias",
        "descricao": """Boa Tarde,
Informamos que o processo de correcao das inconsistencias do e-SUS for realizado com sucesso. Agradecemos a todos os envolvidos pela colaboracao e empenho durante esse periodo.
Atenciosamente/Best Regards
"""
    },
    {
        "client": "Balne",
        "tempo": "0130",
        "assunto": ">Cliente.: Balneario >Tela.: Exportacao e-SUS AB Atencao Basica >Atividade: Correcao das Inconsistencias",
        "descricao": """Boa Tarde,
Informamos que o processo de correcao das inconsistencias do e-SUS for realizado com sucesso. Agradecemos a todos os envolvidos pela colaboracao e empenho durante esse periodo.
Atenciosamente/Best Regards
"""
    },
    {
        "client": "Balne",
        "tempo": "0130",
        "assunto": ">Cliente.: Balneario >Tela.: Estoque >Atividade: Requisicoes de insumos",
        "descricao": """Bom dia, 
Informamos que o processo de requisicao de insumos foi finalizado. Agradecemos a todos os envolvidos pela colaboracao e empenho durante esse período.
Atenciosamente/Best Regards
"""
    }
]

# %%
def play_ticket(client, tempo, assunto, descricao):
    time.sleep(2.16)
    pa.click(81, 137)  # Mouse click at (81, 137)
    time.sleep(2.16)
    pa.click(100, 200)
    time.sleep(4.58)
    pa.click(147, 298)  # Mouse click at (147, 298)
    time.sleep(1.44)
    pa.write(client)  # Type: s
    time.sleep(1.55)
    pa.click(154, 344)  # Mouse click at (154, 344)
    time.sleep(1.67)
    pa.click(122, 420)  # Mouse click at (122, 420)
    time.sleep(1.48)
    pa.write(client)  # Type: s
    time.sleep(1.57)
    pa.click(124, 486)  # Mouse click at (124, 486)
    time.sleep(1.00)
    pa.click(126, 505)  # Mouse click at (126, 505)
    time.sleep(1.99)
    pa.click(114, 557)  # Mouse click at (114, 557)
    time.sleep(2.35)
    pa.click(127, 693)  # Mouse click at (127, 693)
    time.sleep(2.39)
    pa.click(302, 601)  # Mouse click at (302, 601)
    time.sleep(2.14)
    pa.click(184, 499)  # Mouse click at (184, 499)
    time.sleep(1.96)
    pa.click(168, 594)  # Mouse click at (168, 594)
    time.sleep(3.28)
    pa.click(143, 434)  # Mouse click at (143, 434)
    time.sleep(3.27)
    pa.click(190, 684)  # Mouse click at (190, 684)
    time.sleep(2.20)
    pa.write('g')  # Type: g
    time.sleep(0.20)
    pa.write('e')  # Type: e
    time.sleep(0.09)
    pa.write('r')  # Type: r
    time.sleep(1.63)
    pa.click(189, 645)  # Mouse click at (189, 645)
    time.sleep(4.04)
    pa.click(914, 251)  # Mouse click at (914, 251)
    time.sleep(4.81)
    pa.write(assunto)  # Type: s
    time.sleep(1.02)
    pa.click(435, 357)  # Mouse click at (435, 357)
    time.sleep(0.75)
    pa.write(descricao) # Type: s
    time.sleep(1.60)
    pa.click(1151, 201)  # Mouse click at (1151, 201)
    time.sleep(1.82)
    pa.click(1159, 390)  # Mouse click at (1159, 390)
    time.sleep(1.35)
    pa.click(1161, 396)  # Mouse click at (1161, 396)
    time.sleep(1.09)
    pa.click(1161, 396)  # Mouse click at (1161, 396)
    time.sleep(2.28)
    pa.click(1035, 407)  # Mouse click at (1035, 407)
    time.sleep(1.13)
    pa.click(1193, 608)  # Mouse click at (1193, 608)
    time.sleep(1.94)
    pa.write(tempo)  # Type: 0
    time.sleep(3.79)
    pa.click(1177, 721)  # Mouse click at (1177, 721)
    time.sleep(2.65)
    pa.click(903, 440)  # Mouse click at (903, 440)

# %%
max_len = len(entries)

print(f"\nAvailable entries (0 to {max_len - 1}):")
for i, entry in enumerate(entries):
    print(f"{i}: {entry['client']} - {entry['assunto']}")

while True:

    user_input = input(f"Enter the indices of entries to use (max {max_len}, separated by spaces): ")
    
    try:
        # Converter entrada para uma lista de índices
        indices = list(map(int, user_input.split()))
        
        # Validações
        if len(indices) > max_len:
            raise ValueError("Input exceeds the maximum allowed length.")
        if not all(0 <= idx < max_len for idx in indices):
            raise ValueError("One or more indices are out of range.")
        break  # Input válido, sair do loop
    except ValueError as e:
        print(f"Invalid input: {e}. Please try again.")

# Iterar sobre os índices selecionados
print("\nProcessing selected entries:")
print(indices)
for number, entry in enumerate(entries):
    if number in indices:
        continue
    play_ticket(entry["client"], entry["tempo"], entry["assunto"], entry["descricao"])
# Out:
# Available entries (0 to 6):
# 0: sinnc s - >Cliente.: Sinnc >Tela.: Geral >Atividade.: Teste - Impressao
# 1: sinnc s - >Cliente.: Sinnc >Tela.: Geral >Atividade.: Verificacao - Senhas
# 2: sinnc s - >Cliente.: Sinnc >Tela.: Geral >Atividade.: Verificacao - cadSUS
# 3: Iju - >Cliente.: Ijui >Tela.: Exportação e-SUS AB Atencao Basica >Atividade: Correcao das Inconsistencias
# 4: Chapec - >Cliente.: Chapeco >Tela.: Exportacao e-SUS AB Atencao Basica >Atividade: Correcao das Inconsistencias
# 5: Balne - >Cliente.: Balneario >Tela.: Exportacao e-SUS AB Atencao Basica >Atividade: Correcao das Inconsistencias
# 6: Balne - >Cliente.: Balneario >Tela.: Estoque >Atividade: Requisicoes de insumos
#
# Processing selected entries:
