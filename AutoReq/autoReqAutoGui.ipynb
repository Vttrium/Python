# %%
# IMPORTS E CARREGAMENTO DE ARQUIVOS

import pyautogui as pa
import pyperclip as pe
import time
import keyboard 
import pandas as pd
from pathlib import Path

pasta = Path(r'C:/Users/SINNCAPPLE/Documents/VSCodeProjects/PythonProjects/CursoPython/AutoReq/SendoUsado')

arquivos = list(pasta.iterdir())

IndexDoArquivo = 0

if arquivos[IndexDoArquivo].is_file():
    arquivo = arquivos[IndexDoArquivo]
    print("O arquivo na pasta é:", arquivo)
else:
    print("Não há exatamente um arquivo na pasta.")

all_sheets = pd.read_excel(arquivo, sheet_name=None)
sheet_names = list(all_sheets.keys())
# Out:
# O arquivo na pasta é: C:\Users\SINNCAPPLE\Documents\VSCodeProjects\PythonProjects\CursoPython\AutoReq\SendoUsado\Exemplo de Formatacao.xlsx

# %%
def preencher_campos(listCodigoQtd):
    """
    Função para preencher campos em uma interface com base na lista de códigos e quantidades.
    
    Parâmetros:
        listCodigoQtd (list): Lista de tuplas [(codigo, quantidade), ...]
    """
    inativados_duplicados = []  # Lista para armazenar valores duplicados/inativos

    for item in range(len(listCodigoQtd)):
        # Inserir o código no primeiro campo
        pa.click(-1373, 330)  # Clica no campo do primeiro input
        time.sleep(0.2)
        pa.hotkey('ctrl', 'a')  # Seleciona o texto atual
        pa.hotkey('ctrl', 'c')  # Copia o texto para o clipboard

        # Captura o valor do clipboard
        current_value = pe.paste().strip()  # Remove espaços ou quebras de linha
        
        # Verifica se o campo está preenchido
        if current_value != "":
            inativados_duplicados.append(current_value)
            pa.hotkey('ctrl', 'a')  # Seleciona todo o texto
            pa.hotkey('delete')  # Apaga o texto selecionado

        # Insere o novo código
        pa.write(str(listCodigoQtd[item][0]))  # Escreve o código
        time.sleep(1.5)
        pa.hotkey('tab')  # Avança para o próximo campo

        # Inserir a quantidade no segundo campo
        pa.hotkey('ctrl', 'a')  # Seleciona o texto atual no segundo campo
        pa.hotkey('ctrl', 'c')  # Copia o texto para o clipboard

        # Captura o valor do clipboard
        current_value = pe.paste().strip()  # Remove espaços ou quebras de linha

        # Verifica se o campo está preenchido
        if current_value != "":
            pa.hotkey('ctrl', 'a')  # Seleciona todo o texto
            pa.hotkey('delete')  # Apaga o texto selecionado

        # Insere a nova quantidade
        pa.write(str(listCodigoQtd[item][1]))  # Escreve a quantidade
        pa.hotkey('tab')  # Avança ou finaliza
        time.sleep(0.2)
        if item == len(listCodigoQtd) - 1:
            pa.hotkey('tab')
        pa.hotkey('enter')  # Confirma os dados
        time.sleep(1)   
        
        
        
    return inativados_duplicados  # Retorna os valores duplicados/inativos, caso existam

# %%
def play_971(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.42)
    pa.click(-1824, -76)  # Mouse click at (-1824, -76)
    time.sleep(4.82)
    pa.click(-1402, 570)  # Mouse click at (-1402, 570)
    time.sleep(3.06)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.32)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.86)
    pa.write(Unidade)
    time.sleep(2.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.78)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.52)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.67)
    pa.click(-1903, 11)  # Mouse click at (-1903, 11)
    time.sleep(1.74)
    pa.click(-1580, 311)  # Mouse click at (-1580, 311)
    time.sleep(2.42)
    pa.click(-1742, 294)  # Mouse click at (-1742, 294)
    time.sleep(3.05)
    pa.click(-1700, 42)  # Mouse click at (-1700, 42)
    time.sleep(2.24)
    pa.click(-1827, 863)  # Mouse click at (-1827, 863)
    time.sleep(2.35)
    pa.click(-1764, 99)  # Mouse click at (-1764, 99)
    time.sleep(1.07)
    pa.click(-1845, 134)  # Mouse click at (-1845, 134)
    time.sleep(2.72)
    pa.click(-1606, 318)  # Mouse click at (-1606, 318)
    time.sleep(1.37)
    
    preencher_campos(listCodigoQtd)
    
    time.sleep(3.01)
    pa.click(-1776, 857)  # Mouse click at (-1776, 857)
    time.sleep(3.68)
    pa.click(-1831, 74)  # Mouse click at (-1831, 74)
    time.sleep(2.30)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.13)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.51)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(4.24)
    pa.click(-1469, 858)  # Mouse click at (-1469, 858)
    time.sleep(5.16)
    pa.click(-1069, 45)  # Mouse click at (-1069, 45)
    time.sleep(5.32)
    pa.write(arquivo_nome)
    time.sleep(2.20)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(3.68)
    pa.click(-1017, 871)  # Mouse click at (-1017, 871)
    time.sleep(3.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)

# %%
def play_135(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.42)
    pa.click(-1824, -76)  # Mouse click at (-1824, -76)
    time.sleep(4.82)
    pa.click(-1402, 570)  # Mouse click at (-1402, 570)
    time.sleep(3.06)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.32)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.86)
    pa.write(Unidade)
    time.sleep(2.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.78)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.52)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.67)
    pa.click(-1903, 11)  # Mouse click at (-1903, 11)
    time.sleep(1.74)
    pa.click(-1580, 311)  # Mouse click at (-1580, 311)
    time.sleep(2.42)
    pa.click(-1742, 294)  # Mouse click at (-1742, 294)
    time.sleep(3.05)
    pa.click(-1700, 42)  # Mouse click at (-1700, 42)
    time.sleep(2.24)
    pa.click(-1827, 863)  # Mouse click at (-1827, 863)
    time.sleep(2.35)
    pa.click(-1764, 99)  # Mouse click at (-1764, 99)
    time.sleep(1.07)
    pa.click(-1845, 134)  # Mouse click at (-1845, 134)
    time.sleep(2.72)
    pa.click(-1606, 318)  # Mouse click at (-1606, 318)
    time.sleep(1.37)
    
    preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(3.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(3.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(1.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(3.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)

# %%
def play_118(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.42)
    pa.click(-1824, -76)  # Mouse click at (-1824, -76)
    time.sleep(4.82)
    pa.click(-1402, 570)  # Mouse click at (-1402, 570)
    time.sleep(3.06)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.32)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.86)
    pa.write(Unidade)
    time.sleep(2.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.78)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.52)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.67)
    pa.click(-1903, 11)  # Mouse click at (-1903, 11)
    time.sleep(1.74)
    pa.click(-1580, 311)  # Mouse click at (-1580, 311)
    time.sleep(2.42)
    pa.click(-1742, 294)  # Mouse click at (-1742, 294)
    time.sleep(3.05)
    pa.click(-1700, 42)  # Mouse click at (-1700, 42)
    time.sleep(2.24)
    pa.click(-1827, 863)  # Mouse click at (-1827, 863)
    time.sleep(2.35)
    pa.click(-1764, 99)  # Mouse click at (-1764, 99)
    time.sleep(1.07)
    pa.click(-1845, 134)  # Mouse click at (-1845, 134)
    time.sleep(2.72)
    pa.click(-1606, 318)  # Mouse click at (-1606, 318)
    time.sleep(1.37)
    
    preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(3.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(3.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(1.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(3.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)

# %%
def play_70(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(3.14)
    pa.click(-1828, -74)  # Mouse click at (-1828, -74)
    time.sleep(5.58)
    pa.click(-1426, 566)  # Mouse click at (-1426, 566)
    time.sleep(2.60)
    pa.click(-1242, 426)  # Mouse click at (-1242, 426)
    time.sleep(1.44)
    pa.write(Unidade)
    time.sleep(3.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.30)
    pa.click(-1198, 448)  # Mouse click at (-1198, 448)
    time.sleep(2.82)
    pa.click(-1477, 539)  # Mouse click at (-1477, 539)
    time.sleep(2.96)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.30)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(5.96)
    pa.click(-1893, 9)  # Mouse click at (-1893, 9)
    time.sleep(1.73)
    pa.click(-1574, 307)  # Mouse click at (-1574, 307)
    time.sleep(3.56)
    pa.click(-1811, 296)  # Mouse click at (-1811, 296)
    time.sleep(3.88)
    pa.click(-1697, 48)  # Mouse click at (-1697, 48)
    time.sleep(2.72)
    pa.click(-1851, 862)  # Mouse click at (-1851, 862)
    time.sleep(2.69)
    pa.click(-1755, 111)  # Mouse click at (-1755, 111)
    time.sleep(2.02)
    pa.click(-1849, 143)  # Mouse click at (-1849, 143)
    time.sleep(1.45)
    
    preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(3.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(3.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(1.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(3.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)

# %%
def play_14(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.84)
    pa.click(-1828, -75)  # Mouse click at (-1828, -75)
    time.sleep(5.04)
    pa.click(-1441, 577)  # Mouse click at (-1441, 577)
    time.sleep(1.90)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.35)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.91)
    pa.write(Unidade)
    time.sleep(1.59)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.89)
    pa.click(-1201, 449)  # Mouse click at (-1201, 449)
    time.sleep(4.15)
    pa.click(-1438, 621)  # Mouse click at (-1438, 621)
    time.sleep(2.52)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(1.60)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(4.68)
    pa.click(-1892, 7)  # Mouse click at (-1892, 7)
    time.sleep(1.70)
    pa.click(-1570, 310)  # Mouse click at (-1570, 310)
    time.sleep(2.72)
    pa.click(-1792, 291)  # Mouse click at (-1792, 291)
    time.sleep(3.84)
    pa.click(-1698, 54)  # Mouse click at (-1698, 54)
    time.sleep(2.74)
    pa.click(-1840, 862)  # Mouse click at (-1840, 862)
    time.sleep(4.45)
    pa.click(-1754, 110)  # Mouse click at (-1754, 110)
    time.sleep(1.76)
    pa.click(-1846, 135)  # Mouse click at (-1846, 135)
    time.sleep(1.37)
    
    preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(3.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(3.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(1.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(3.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)

# %%
def play_13(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.91)
    pa.click(-1822, -76)  # Mouse click at (-1822, -76)
    time.sleep(3.76)
    pa.click(-1398, 570)  # Mouse click at (-1398, 570)
    time.sleep(1.80)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.39)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(0.81)
    pa.write('1')  # Type: 1
    time.sleep(0.82)
    pa.write('3')  # Type: 3
    time.sleep(1.48)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.43)
    pa.click(-1205, 447)  # Mouse click at (-1205, 447)
    time.sleep(2.30)
    pa.click(-1368, 582)  # Mouse click at (-1368, 582)
    time.sleep(2.68)
    pa.click(-1317, 482)  # Mouse click at (-1317, 482)
    time.sleep(5.52)
    pa.click(-1886, 2)  # Mouse click at (-1886, 2)
    time.sleep(1.64)
    pa.click(-1573, 311)  # Mouse click at (-1573, 311)
    time.sleep(3.16)
    pa.click(-1781, 293)  # Mouse click at (-1781, 293)
    time.sleep(3.51)
    pa.click(-1703, 49)  # Mouse click at (-1703, 49)
    time.sleep(3.92)
    pa.click(-1842, 858)  # Mouse click at (-1842, 858)
    time.sleep(2.76)
    pa.click(-1763, 107)  # Mouse click at (-1763, 107)
    time.sleep(1.97)
    pa.click(-1854, 136)  # Mouse click at (-1854, 136)
    time.sleep(1.37)
    
    preencher_campos(listCodigoQtd)
    
    time.sleep(3.01)
    pa.click(-1776, 857)  # Mouse click at (-1776, 857)
    time.sleep(3.68)
    pa.click(-1831, 74)  # Mouse click at (-1831, 74)
    time.sleep(2.30)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.13)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.51)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(4.24)
    pa.click(-1469, 858)  # Mouse click at (-1469, 858)
    time.sleep(5.16)
    pa.click(-1069, 45)  # Mouse click at (-1069, 45)
    time.sleep(5.32)
    pa.write(arquivo_nome)
    time.sleep(2.20)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(3.68)
    pa.click(-1017, 871)  # Mouse click at (-1017, 871)
    time.sleep(3.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)

# %%
""" DISPLAYS E PRINTS """; NumeroDaTabela = 1

df = all_sheets[sheet_names[NumeroDaTabela - 1]]

Codigo = df.iloc[:, 0]
qtd = df.iloc[:, 3]
Codigo = Codigo.dropna(how='all', axis=0)
qtd = qtd.dropna(how='all', axis=0)
qtd = qtd.drop(index=0)
Codigo = Codigo.drop(index=0)

listCodigoQtd = []
for codigos in (Codigo):
    codigos = str(codigos)
    codigos = int(codigos.split(" -")[0])
    listCodigoQtd.append([int(codigos)])
for num, qtds in enumerate(qtd):
    if qtds < 1:
        qtds = 1
    listCodigoQtd[num].append(round(qtds))

print(listCodigoQtd)
display(df)
# Out:
# [[1882, 2688], [2504, 301], [6719, 1], [6721, 3], [9326, 17], [2491, 277], [9203, 664], [6639, 22], [6638, 23], [6701, 84], [6678, 315], [6679, 181], [6897, 16], [2483, 5], [2549, 102], [3968, 2942], [4538, 46], [3776, 465], [8569, 22], [8568, 559], [6659, 4242], [4045, 2264], [6660, 30], [4753, 204], [6886, 169], [6681, 6], [6682, 2], [1672, 217], [6898, 9], [6707, 29], [4390, 518], [5232, 6], [2474, 1298], [7414, 235], [7415, 1737], [4028, 1225], [9328, 392], [6709, 815], [9329, 211], [7362, 998], [2007, 16], [2008, 722], [9325, 3], [3692, 159], [6837, 3], [4740, 233], [6711, 1186], [6712, 56], [5404, 110], [5405, 19], [6672, 788], [6714, 4], [2553, 231], [6965, 775], [4541, 1], [5214, 24], [4544, 103], [7430, 251], [2496, 1], [6661, 107], [4077, 937], [2286, 18], [6669, 2], [9333, 1], [7416, 39], [5520, 9], [3927, 68], [4997, 532], [2241, 417], [4388, 72], [5228, 57], [6665, 6486], [9330, 3377], [9321, 13], [6694, 18], [6666, 2206], [7804, 1758], [7423, 2618], [9324, 139], [2495, 140], [6691, 1], [6889, 272], [7114, 123], [6922, 1038], [6716, 5], [6700, 1], [9334, 1], [6717, 1], [6850, 16], [8834, 1], [5011, 21], [6879, 101], [2552, 165], [2288, 135], [2182, 253], [3928, 4], [6667, 622], [4037, 59], [5387, 2639], [2185, 993], [2264, 758], [8601, 1658], [8816, 3], [4543, 51], [2330, 1], [1877, 181], [7397, 2], [2186, 5262], [7121, 14], [2291, 6], [8585, 2], [7392, 12], [7425, 1720], [6674, 118], [9248, 84], [4660, 30], [9249, 30], [6637, 11], [6684, 11], [9277, 89], [7412, 98], [6946, 30], [8600, 2119], [8145, 593], [7976, 71], [2562, 88], [5234, 154], [4430, 183], [1878, 2], [6653, 1666], [6651, 1161], [9438, 37], [6652, 1913], [5013, 14], [7115, 16], [7108, 467], [6636, 11178], [6699, 12], [5233, 3445], [7052, 508], [6884, 237], [3418, 757], [9280, 2], [9108, 1], [2115, 7], [6662, 172], [4756, 15], [2287, 18], [6642, 1], [9451, 1], [4887, 2], [2498, 5], [6663, 359], [6654, 59], [3862, 9], [6646, 2160], [7456, 4], [7457, 1], [7458, 21], [6656, 344], [6655, 4], [7113, 250], [2563, 47], [4546, 1744], [2117, 2], [7116, 2], [9323, 12], [8127, 24], [2475, 293], [2476, 314], [3930, 346], [6834, 60], [2188, 852], [2850, 2], [9439, 3], [7223, 876], [7413, 21], [3351, 93], [2485, 39], [5946, 544], [6874, 3549], [4264, 12], [7428, 61], [7140, 7202], [2018, 1], [2014, 152], [2488, 1931], [6839, 7], [2118, 1], [8815, 127], [6892, 6], [8086, 87], [9447, 2], [6893, 320], [6842, 4], [6896, 342], [6657, 1001], [5590, 7], [7403, 191], [1868, 11], [7406, 46]]
#                   971 - FARMACIA DESCENTRALIZADA OESTE  5377855  448154.58  \
# 0                  226 - DISPENSARIO DA FARMACIA OESTE  5377855  448154.58
# 1                                    1882 - AAS 100 MG   129013   10751.08
# 2                              2504 - ACICLOVIR 200 MG    14430    1202.50
# 3                              6719 - ACICLOVIR 400 MG       23       1.92
# 4              6721 - ACICLOVIR 50 MG/G CREME TUBO 10G      129      10.75
# ..                                                 ...      ...        ...
# 197                   6657 - VALPROATO DE SODIO 500 MG    48050    4004.17
# 198          5590 - VALPROATO DE SODIO 50MG/ML XPE ...      332      27.67
# 199                       7403 - VARFARINA SODICA 5 MG     9186     765.50
# 200                         1868 - VERAPAMIL 120 MG LR      540      45.00
# 201                             7406 - VERAPAMIL 80 MG     2190     182.50
#
#       112038.645
# 0    112038.6450
# 1      2687.7700
# 2       300.6250
# 3         1.0000
# 4         2.6875
# ..           ...
# 197    1001.0425
# 198       6.9175
# 199     191.3750
# 200      11.2500
# 201      45.6250
#
# [202 rows x 4 columns]

# %%
funcoes = [play_971, play_135, play_118, play_70, play_14, play_13]

for tabela in range(len(sheet_names)):
    
    if keyboard.is_pressed('esc'):
        print("Execução interrompida pelo usuário.")
        break

    df = all_sheets[sheet_names[tabela]]

    Unidade = df.columns[0].split(" - ")[0]
    Dispensario = df.iloc[0, 0].split(" - ")[0]
    
    arquivo_nome = f'Requisicao de Insumos - Unidade {Unidade} - Local{Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'

    Codigo = df.iloc[:, 0]
    qtd = df.iloc[:, 3]
    Codigo = Codigo.dropna(how='all', axis=0)
    qtd = qtd.dropna(how='all', axis=0)
    qtd = qtd.drop(index=0)
    Codigo = Codigo.drop(index=0)

    listCodigoQtd = []
    for codigos in (Codigo):
        codigos = str(codigos)
        codigos = int(codigos.split(" -")[0])
        listCodigoQtd.append([codigos])
    for num, qtds in enumerate(qtd):
        if qtds < 1:
            qtds = 1
        listCodigoQtd[num].append(round(qtds))

    funcoes[tabela](listCodigoQtd, Unidade, arquivo_nome)  # Chama a função associada a tabela
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 33
#      30         qtds = 1
#      31     listCodigoQtd[num].append(round(qtds))
# ---> 33 funcoes[tabela](listCodigoQtd, Unidade, arquivo_nome)  # Chama a função associada a tabela
#
# Cell In[17], line 4, in play_971(listCodigoQtd, Unidade, arquivo_nome)
#       2 time.sleep(2.42)
#       3 pa.click(-1824, -76)  # Mouse click at (-1824, -76)
# ----> 4 time.sleep(4.82)
#       5 pa.click(-1402, 570)  # Mouse click at (-1402, 570)
#       6 time.sleep(3.06)
#
# KeyboardInterrupt:
