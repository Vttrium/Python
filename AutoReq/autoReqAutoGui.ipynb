# %%
# IMPORTS E CARREGAMENTO DE ARQUIVOS

import pyautogui as pa
import pyperclip as pe
import time
import re
import pandas as pd
from pathlib import Path
import os

pasta = Path(r'C:/Users/SINNCAPPLE/Documents/VSCodeProjects/PythonProjects/CursoPython/AutoReq/SendoUsado')

arquivos = list(pasta.iterdir())

IndexDoArquivo = 0

if arquivos[IndexDoArquivo].is_file():
    arquivo = arquivos[IndexDoArquivo]
    print("O arquivo na pasta é:", arquivo)
else:
    print("Não há exatamente um arquivo na pasta.")

all_sheets = pd.read_excel(arquivo, sheet_name=None)
sheet_names = list(all_sheets.keys())
# Out:
# O arquivo na pasta é: C:\Users\SINNCAPPLE\Documents\VSCodeProjects\PythonProjects\CursoPython\AutoReq\SendoUsado\Exemplo de Formatacao.xlsx

# %%
def preencher_campos(listCodigoQtd):
    """
    Função para preencher campos em uma interface com base na lista de códigos e quantidades.
    
    Parâmetros:
        listCodigoQtd (list): Lista de tuplas [(codigo, quantidade), ...]
    """
    inativados_duplicados = []  # Lista para armazenar valores duplicados/inativos

    for item in range(len(listCodigoQtd)):

        pa.click(-1373, 330)  # Clica no campo do primeiro input
        time.sleep(2)
        pa.click(-1373, 330)  # Clica no campo do primeiro input
        pa.hotkey('ctrl', 'a')  # Seleciona o texto atual
        pa.hotkey('ctrl', 'c')  # Copia o texto para o clipboard

        # Captura o valor do clipboard
        current_value = pe.paste()  # Remove espaços ou quebras de linha
        # Verifica se o campo está preenchido
        if current_value and current_value != "":
            inativados_duplicados.append(str(current_value))
            pa.hotkey('ctrl', 'a')
            pa.hotkey('delete')  # Apaga o texto selecionado

        # Insere o novo código
        pa.write(str(listCodigoQtd[item][0]))  # Escreve o código
        time.sleep(2)
        pa.hotkey('tab')  # Avança para o próximo campo

        # Inserir a quantidade no segundo campo
        pa.hotkey('ctrl', 'a')  # Seleciona o texto atual no segundo campo
        pa.hotkey('ctrl', 'c')  # Copia o texto para o clipboard

        # Captura o valor do clipboard
        current_value = pe.paste()  # Remove espaços ou quebras de linha

        # Verifica se o campo está preenchido
        if current_value != "":
            pa.hotkey('ctrl', 'a')  # Seleciona todo o texto
            pa.hotkey('delete')  # Apaga o texto selecionado

        # Insere a nova quantidade
        pa.write(str(listCodigoQtd[item][1]))  # Escreve a quantidade
        pa.hotkey('tab')  # Avança ou finaliza
        time.sleep(2.5)
        if item == len(listCodigoQtd) - 1:
            pa.hotkey('tab')
        pa.hotkey('enter')  # Confirma os dados
        time.sleep(2)
        
    return inativados_duplicados

# %%
def play_971(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.42)
    pa.click(-1824, -76)  # Mouse click at (-1824, -76)
    time.sleep(6.82)
    pa.click(-1402, 570)  # Mouse click at (-1402, 570)
    time.sleep(5.06)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.32)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.86)
    pa.write(Unidade)
    time.sleep(2.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.78)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.52)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.67)
    pa.click(-1903, 11)  # Mouse click at (-1903, 11)
    time.sleep(2.74)
    pa.click(-1580, 311)  # Mouse click at (-1580, 311)
    time.sleep(2.42)
    pa.click(-1742, 294)  # Mouse click at (-1742, 294)
    time.sleep(5.05)
    pa.click(-1700, 42)  # Mouse click at (-1700, 42)
    time.sleep(2.24)
    pa.click(-1827, 863)  # Mouse click at (-1827, 863)
    time.sleep(2.35)
    pa.click(-1764, 99)  # Mouse click at (-1764, 99)
    time.sleep(2.07)
    pa.click(-1845, 134)  # Mouse click at (-1845, 134)
    time.sleep(2.72)
    pa.click(-1606, 318)  # Mouse click at (-1606, 318)
    time.sleep(2.37)
    
    inativos = preencher_campos(listCodigoQtd)
    
    time.sleep(5.01)
    pa.click(-1776, 857)  # Mouse click at (-1776, 857)
    time.sleep(5.68)
    pa.click(-1831, 74)  # Mouse click at (-1831, 74)
    time.sleep(2.30)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.13)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.51)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.24)
    pa.click(-1469, 858)  # Mouse click at (-1469, 858)
    time.sleep(5.16)
    pa.click(-1069, 45)  # Mouse click at (-1069, 45)
    time.sleep(5.32)
    pa.write(arquivo_nome)
    time.sleep(2.20)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(5.68)
    pa.click(-1017, 871)  # Mouse click at (-1017, 871)
    time.sleep(5.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)
    
    return inativos

# %%
def play_135(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.42)
    pa.click(-1824, -76)  # Mouse click at (-1824, -76)
    time.sleep(6.82)
    pa.click(-1402, 570)  # Mouse click at (-1402, 570)
    time.sleep(5.06)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.32)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.86)
    pa.write(Unidade)
    time.sleep(2.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.78)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.52)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.67)
    pa.click(-1903, 11)  # Mouse click at (-1903, 11)
    time.sleep(2.74)
    pa.click(-1580, 311)  # Mouse click at (-1580, 311)
    time.sleep(2.42)
    pa.click(-1742, 294)  # Mouse click at (-1742, 294)
    time.sleep(5.05)
    pa.click(-1700, 42)  # Mouse click at (-1700, 42)
    time.sleep(2.24)
    pa.click(-1827, 863)  # Mouse click at (-1827, 863)
    time.sleep(2.35)
    pa.click(-1764, 99)  # Mouse click at (-1764, 99)
    time.sleep(2.07)
    pa.click(-1845, 134)  # Mouse click at (-1845, 134)
    time.sleep(2.72)
    pa.click(-1606, 318)  # Mouse click at (-1606, 318)
    time.sleep(2.37)
    
    inativos = preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(5.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(5.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(2.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(5.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)
    
    return inativos

# %%
def play_118(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.42)
    pa.click(-1824, -76)  # Mouse click at (-1824, -76)
    time.sleep(6.82)
    pa.click(-1402, 570)  # Mouse click at (-1402, 570)
    time.sleep(5.06)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.32)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.86)
    pa.write(Unidade)
    time.sleep(2.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.78)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.52)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.67)
    pa.click(-1903, 11)  # Mouse click at (-1903, 11)
    time.sleep(2.74)
    pa.click(-1580, 311)  # Mouse click at (-1580, 311)
    time.sleep(2.42)
    pa.click(-1742, 294)  # Mouse click at (-1742, 294)
    time.sleep(5.05)
    pa.click(-1700, 42)  # Mouse click at (-1700, 42)
    time.sleep(2.24)
    pa.click(-1827, 863)  # Mouse click at (-1827, 863)
    time.sleep(2.35)
    pa.click(-1764, 99)  # Mouse click at (-1764, 99)
    time.sleep(2.07)
    pa.click(-1845, 134)  # Mouse click at (-1845, 134)
    time.sleep(2.72)
    pa.click(-1606, 318)  # Mouse click at (-1606, 318)
    time.sleep(2.37)
    
    inativos = preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(5.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(5.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(2.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(5.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)
    
    return inativos

# %%
def play_70(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(5.14)
    pa.click(-1828, -74)  # Mouse click at (-1828, -74)
    time.sleep(5.58)
    pa.click(-1426, 566)  # Mouse click at (-1426, 566)
    time.sleep(2.60)
    pa.click(-1242, 426)  # Mouse click at (-1242, 426)
    time.sleep(2.44)
    pa.write(Unidade)
    time.sleep(5.04)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.30)
    pa.click(-1198, 448)  # Mouse click at (-1198, 448)
    time.sleep(2.82)
    pa.click(-1477, 539)  # Mouse click at (-1477, 539)
    time.sleep(2.96)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.30)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(5.96)
    pa.click(-1893, 9)  # Mouse click at (-1893, 9)
    time.sleep(2.73)
    pa.click(-1574, 307)  # Mouse click at (-1574, 307)
    time.sleep(5.56)
    pa.click(-1811, 296)  # Mouse click at (-1811, 296)
    time.sleep(5.88)
    pa.click(-1697, 48)  # Mouse click at (-1697, 48)
    time.sleep(2.72)
    pa.click(-1851, 862)  # Mouse click at (-1851, 862)
    time.sleep(2.69)
    pa.click(-1755, 111)  # Mouse click at (-1755, 111)
    time.sleep(2.02)
    pa.click(-1849, 143)  # Mouse click at (-1849, 143)
    time.sleep(2.45)
    
    inativos = preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(5.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(5.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(2.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(5.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)
    
    return inativos

# %%
def play_14(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.84)
    pa.click(-1828, -75)  # Mouse click at (-1828, -75)
    time.sleep(5.04)
    pa.click(-1441, 577)  # Mouse click at (-1441, 577)
    time.sleep(2.90)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.35)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.91)
    pa.write(Unidade)
    time.sleep(2.59)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.89)
    pa.click(-1201, 449)  # Mouse click at (-1201, 449)
    time.sleep(6.15)
    pa.click(-1438, 621)  # Mouse click at (-1438, 621)
    time.sleep(2.52)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.60)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.68)
    pa.click(-1892, 7)  # Mouse click at (-1892, 7)
    time.sleep(2.70)
    pa.click(-1570, 310)  # Mouse click at (-1570, 310)
    time.sleep(2.72)
    pa.click(-1792, 291)  # Mouse click at (-1792, 291)
    time.sleep(5.84)
    pa.click(-1698, 54)  # Mouse click at (-1698, 54)
    time.sleep(2.74)
    pa.click(-1840, 862)  # Mouse click at (-1840, 862)
    time.sleep(6.45)
    pa.click(-1754, 110)  # Mouse click at (-1754, 110)
    time.sleep(2.76)
    pa.click(-1846, 135)  # Mouse click at (-1846, 135)
    time.sleep(2.37)
    
    inativos = preencher_campos(listCodigoQtd)
    
    time.sleep(2.64)
    pa.click(-1765, 855)  # Mouse click at (-1765, 855)
    time.sleep(5.84)
    pa.click(-991, 16)  # Mouse click at (-991, 16)
    time.sleep(2.80)
    pa.click(-1070, 39)  # Mouse click at (-1070, 39)
    time.sleep(5.02)
    pa.write(arquivo_nome)  # Type: f
    time.sleep(2.69)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(2.90)
    pa.click(-1006, 872)  # Mouse click at (-1006, 872)
    time.sleep(5.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)
    
    return inativos

# %%
def play_13(listCodigoQtd, Unidade, arquivo_nome):
    time.sleep(2.91)
    pa.click(-1822, -76)  # Mouse click at (-1822, -76)
    time.sleep(5.76)
    pa.click(-1398, 570)  # Mouse click at (-1398, 570)
    time.sleep(2.80)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.39)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.81)
    pa.write(str(Unidade))  # Type: 1
    time.sleep(2.48)
    pa.hotkey('tab')  # Hotkey: tab
    time.sleep(2.43)
    pa.click(-1204, 449)  # Mouse click at (-1204, 449)
    time.sleep(2.38)
    pa.click(-1428, 580)  # Mouse click at (-1428, 580)
    time.sleep(2.30)
    pa.click(-1317, 482)  # Mouse click at (-1317, 482)
    time.sleep(5.52)
    pa.click(-1886, 2)  # Mouse click at (-1886, 2)
    time.sleep(2.64)
    pa.click(-1573, 311)  # Mouse click at (-1573, 311)
    time.sleep(5.16)
    pa.click(-1781, 293)  # Mouse click at (-1781, 293)
    time.sleep(5.51)
    pa.click(-1703, 49)  # Mouse click at (-1703, 49)
    time.sleep(5.92)
    pa.click(-1842, 858)  # Mouse click at (-1842, 858)
    time.sleep(2.76)
    pa.click(-1763, 107)  # Mouse click at (-1763, 107)
    time.sleep(2.97)
    pa.click(-1854, 136)  # Mouse click at (-1854, 136)
    time.sleep(2.37)
    
    inativos = preencher_campos(listCodigoQtd)
    
    time.sleep(5.01)
    pa.click(-1776, 857)  # Mouse click at (-1776, 857)
    time.sleep(5.68)
    pa.click(-1831, 74)  # Mouse click at (-1831, 74)
    time.sleep(2.30)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.13)
    pa.click(-1842, 209)  # Mouse click at (-1842, 209)
    time.sleep(2.51)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(6.24)
    pa.click(-1469, 858)  # Mouse click at (-1469, 858)
    time.sleep(5.16)
    pa.click(-1069, 45)  # Mouse click at (-1069, 45)
    time.sleep(5.32)
    pa.write(arquivo_nome)
    time.sleep(2.20)
    pa.hotkey('enter')  # Hotkey: enter
    time.sleep(5.68)
    pa.click(-1017, 871)  # Mouse click at (-1017, 871)
    time.sleep(5.37)
    pa.click(-1001, 857)  # Mouse click at (-1001, 857)
    
    return inativos

# %%
""" DISPLAYS E PRINTS """; NumeroDaTabela = 6

df = all_sheets[sheet_names[NumeroDaTabela - 1]]

Codigo = df.iloc[:, 0]
qtd = df.iloc[:, 3]
Codigo = Codigo.dropna(how='all', axis=0)
qtd = qtd.dropna(how='all', axis=0)
qtd = qtd.drop(index=0)
Codigo = Codigo.drop(index=0)

Unidade = df.columns[0].split(" - ")[0]
Dispensario = df.iloc[0, 0].split(" - ")[0].strip()

arquivo_nome = f'Requisicao de Insumos - Unidade {Unidade} - Local{Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'
arquivo_inativados = f'Inativados da Requisicao - Unidade {Unidade} - Local {Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'

inativados = []
listCodigoQtd = []
for codigos in (Codigo):
    codigos = str(codigos)
    codigos = int(codigos.split(" -")[0])
    listCodigoQtd.append([int(codigos)])
for num, qtds in enumerate(qtd):
    if qtds < 1:
        qtds = 1
    listCodigoQtd[num].append(round(qtds))
    
i = 1
for item in listCodigoQtd:
    print(str(item) + " - " + str(i))
    i += 1
display(df)
# Out:
# [2504, 98] - 1
# [2504, 7] - 2
# [6719, 1] - 3
# [6721, 11] - 4
# [2491, 1] - 5
# [6639, 2] - 6
# [6638, 6] - 7
# [3776, 26] - 8
# [8568, 1] - 9
# [6660, 1] - 10
# [4753, 8] - 11
# [2008, 1] - 12
# [6713, 1] - 13
# [4541, 648] - 14
# [4077, 2] - 15
# [2286, 2] - 16
# [3927, 39] - 17
# [9330, 1] - 18
# [9321, 1] - 19
# [6694, 1] - 20
# [2495, 5] - 21
# [6889, 4] - 22
# [2552, 4] - 23
# [4037, 1] - 24
# [5387, 1] - 25
# [2291, 1] - 26
# [7392, 41] - 27
# [7425, 1] - 28
# [7038, 8] - 29
# [5013, 16] - 30
# [7108, 1] - 31
# [6699, 9] - 32
# [3418, 1] - 33
# [9108, 1] - 34
# [2115, 9] - 35
# [6662, 1] - 36
# [4756, 1] - 37
# [2287, 1] - 38
# [2498, 99] - 39
# [6646, 1] - 40
# [2563, 26] - 41
# [4546, 1] - 42
# [8127, 11] - 43
# [2475, 1] - 44
# [2850, 1] - 45
# [9439, 1] - 46
# [3351, 1] - 47
# [4264, 1] - 48
# [2018, 466] - 49
# [2014, 125] - 50
# [2488, 1] - 51
# [6839] - 52
#    13 - UE CISS - CENTRO INTEGRADO DE SOLIDARIEDADE E SAUDE  80789  6732.42  \
# 0                  109 - DISPENSARIO DA FARMACIA CISS        80789  6732.42
# 1                             2504 - ACICLOVIR 200 MG         4704   392.00
# 2                             6719 - ACICLOVIR 400 MG          321    26.75
# 3             6721 - ACICLOVIR 50 MG/G CREME TUBO 10G           21     1.75
# 4                            2491 - ACIDO FOLICO 5 MG          510    42.50
# 5           6639 - ALBENDAZOL 40 MG/ML (4%) SUSP. ...            4     0.33
# 6                            6638 - ALBENDAZOL 400 MG          118     9.83
# 7                           3776 - AMOXICILINA 500 MG          290    24.17
# 8           8568 - AMOXICILINA+CLAVULANATO DE POTA...         1241   103.42
# 9           6660 - AZITROMICINA 40 MG/ML SUSP. ORA...            8     0.67
# 10                         4753 - AZITROMICINA 500 MG           50     4.17
# 11                           2008 - CEFALEXINA 500 MG          370    30.83
# 12                         6713 - CLINDAMICINA 300 MG           32     2.67
# 13          4541 - CLORETO SODIO+BENZALC. 0,9% SOL...            5     0.42
# 14          4077 - COMPLEXO B (VITAMINAS B1, B2, B...        31115  2592.92
# 15           2286 - DEXAMETASONA 0,1 % CREME TUBO 10G           82     6.83
# 16                     3927 - DEXCLOROFENIRAMINA 2 MG          110     9.17
# 17                             9330 - DIPIRONA 500 MG         1860   155.00
# 18          9321 - DIPIRONA 500 MG/ML SOL. ORAL FR...           12     1.00
# 19          6694 - DIPIRONA 500 MG/ML SOL. ORAL FR...           15     1.25
# 20                          2495 - ESCOPOLAMINA 10 MG           60     5.00
# 21             6889 - ESCOPOLAMINA+DIPIRONA 10+250 MG          250    20.83
# 22          2552 - ETINILESTRADIOL+LEVONORGESTREL ...          175    14.58
# 23                           4037 - FLUCONAZOL 150 MG          204    17.00
# 24                            5387 - FLUOXETINA 20 MG           56     4.67
# 25          2291 - HIDROXIDO ALUMINIO 60 MG/ML (6%...            2     0.17
# 26          7392 - IBUPROFENO 50 MG/ML SUSP. ORAL ...            5     0.42
# 27                           7425 - IBUPROFENO 600 MG         1975   164.58
# 28                      7038 - LEVONORGESTREL 0,75 MG           16     1.33
# 29                             5013 - LOPERAMIDA 2 MG          408    34.00
# 30                            7108 - LORATADINA 10 MG          781    65.08
# 31          6699 - MEDROXIPROGESTERONA, ACET. 150 ...            4     0.33
# 32                        3418 - METOCLOPRAMIDA 10 MG          420    35.00
# 33          9108 - METRONIDAZOL (BENZOILMETRON.) 4...            1     0.08
# 34          2115 - METRONIDAZOL 100 MG/G GELEIA VA...           19     1.58
# 35                         6662 - METRONIDAZOL 400 MG          414    34.50
# 36          4756 - MICONAZOL 20 MG/G CREME VAG TUB...           25     2.08
# 37          2287 - NEOMICINA+BACITRACINA 5 MG+250 ...           51     4.25
# 38          2498 - NISTATINA 100.000 UI/ML SUSP. O...           12     1.00
# 39                             6646 - OMEPRAZOL 20 MG         4770   397.50
# 40          2563 - PARACETAMOL 200 MG/ML SOL. ORAL...            3     0.25
# 41                           4546 - PARACETAMOL 500MG         1240   103.33
# 42          8127 - PREDNISOLONA 3MG/ML SOL. ORAL F...            2     0.17
# 43                            2475 - PREDNISONA 20 MG          520    43.33
# 44          2850 - RETINOL, ACET. 50.000 UI/ML + C...            3     0.25
# 45          9439 - RETINOL, ACET. 50.000 UI/ML + C...           21     1.75
# 46          3351 - SAIS PARA REIDRATACAO ORAL ENVE...           35     2.92
# 47          4264 - SIMETICONA 75 MG/ML EMULSAO ORA...            4     0.33
# 48          2018 - SULFAMETOXAZOL+TRIMETOPRIMA 40+...           63     5.25
# 49          2014 - SULFAMETOXAZOL+TRIMETOPRIMA 400...        22366  1863.83
# 50           2488 - SULFATO FERROSO CPR - 40 MG FERRO         6012   501.00
# 51          6839 - SULFATO FERROSO GOTAS - 25 MG/M...            4     0.33
#
#             1
# 0   1683.1050
# 1     98.0000
# 2      6.6875
# 3      0.4375
# 4     10.6250
# 5      0.0825
# 6      2.4575
# 7      6.0425
# 8     25.8550
# 9      0.1675
# 10     1.0425
# 11     7.7075
# 12     0.6675
# 13     0.1050
# 14   648.2300
# 15     1.7075
# 16     2.2925
# 17    38.7500
# 18     0.2500
# 19     0.3125
# 20     1.2500
# 21     5.2075
# 22     3.6450
# 23     4.2500
# 24     1.1675
# 25     0.0425
# 26     0.1050
# 27    41.1450
# 28     0.3325
# 29     8.5000
# 30    16.2700
# 31     0.0825
# 32     8.7500
# 33     0.0200
# 34     0.3950
# 35     8.6250
# 36     0.5200
# 37     1.0625
# 38     0.2500
# 39    99.3750
# 40     0.0625
# 41    25.8325
# 42     0.0425
# 43    10.8325
# 44     0.0625
# 45     0.4375
# 46     0.7300
# 47     0.0825
# 48     1.3125
# 49   465.9575
# 50   125.2500
# 51     0.0825

# %%
""" CHAMAR APENAS 1 FUNÇAO """; NumeroDaTabela = 6

df = all_sheets[sheet_names[NumeroDaTabela - 1]]

Codigo = df.iloc[:, 0]
qtd = df.iloc[:, 3]
Codigo = Codigo.dropna(how='all', axis=0)
qtd = qtd.dropna(how='all', axis=0)
qtd = qtd.drop(index=0)
Codigo = Codigo.drop(index=0)

Unidade = df.columns[0].split(" - ")[0]
Dispensario = df.iloc[0, 0].split(" - ")[0].strip()

arquivo_nome = f'Requisicao de Insumos - Unidade {Unidade} - Local {Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'
arquivo_inativados = f'Inativados da Requisicao - Unidade {Unidade} - Local {Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'

inativados = []
listCodigoQtd = [[2504, 1], [2504, 1], [1882, 1]]
# for codigos in (Codigo):
#     codigos = str(codigos)
#     codigos = int(codigos.split(" -")[0])
#     listCodigoQtd.append([int(codigos)])
# for num, qtds in enumerate(qtd):
#     if qtds < 1:
#         qtds = 1
#     listCodigoQtd[num].append(round(qtds))

inativados = play_13(listCodigoQtd, Unidade, arquivo_nome)

i = 1
added_codes = set()  # Conjunto para rastrear códigos já adicionados

with open(arquivo_inativados, "w") as file:
    file.write(f"Codigos da unidade {Unidade}\n")
    file.write(f"Codigos do local {Dispensario}\n\n")
    file.write("Codigos:\n\n")
    
    for codigo in inativados:
        # Use uma expressão regular para extrair todos os números da string
        numeros = re.findall(r'\d+', codigo)
        
        # Verifica se foi encontrado algum número
        if numeros:
            # Pega o primeiro número encontrado na lista
            codigo = numeros[0]
            
            # Verifica se o código extraído está na lista de códigos e não foi adicionado ainda
            if any(int(codigo) == item[0] for item in listCodigoQtd) and codigo not in added_codes:
                file.write(f"    {codigo} -- {i}\n")
                added_codes.add(codigo)  # Adiciona o código ao conjunto de códigos já adicionados
                i += 1

# Caso nenhum código tenha sido registrado, deleta o arquivo
if i == 1:
    os.remove(arquivo_inativados)

# %%
funcoes = [play_971, play_135, play_118, play_70, play_14, play_13]

for tabela in range(len(sheet_names)):

    df = all_sheets[sheet_names[tabela]]

    Codigo = df.iloc[:, 0]
    qtd = df.iloc[:, 3]
    Codigo = Codigo.dropna(how='all', axis=0)
    qtd = qtd.dropna(how='all', axis=0)
    qtd = qtd.drop(index=0)
    Codigo = Codigo.drop(index=0)

    Unidade = df.columns[0].split(" - ")[0]
    Dispensario = df.iloc[0, 0].split(" - ")[0].strip()

    arquivo_nome = f'Requisicao de Insumos - Unidade {Unidade} - Local {Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'
    arquivo_inativados = f'Inativados da Requisicao - Unidade {Unidade} - Local {Dispensario} - Data {time.gmtime().tm_mday}_{time.gmtime().tm_mon}'

    inativados = []
    listCodigoQtd = []
    for codigos in (Codigo):
        codigos = str(codigos)
        codigos = int(codigos.split(" -")[0])
        listCodigoQtd.append([int(codigos)])
    for num, qtds in enumerate(qtd):
        if qtds < 1:
            qtds = 1
        listCodigoQtd[num].append(round(qtds))

    inativados = funcoes[tabela](listCodigoQtd, Unidade, arquivo_nome)

    i = 1
    added_codes = set()  # Conjunto para rastrear códigos já adicionados

    with open(arquivo_inativados, "w") as file:
        file.write(f"Codigos da unidade {Unidade}\n")
        file.write(f"Codigos do local {Dispensario}\n\n")
        file.write("Codigos:\n\n")
        
        for codigo in inativados:
            # Use uma expressão regular para extrair todos os números da string
            numeros = re.findall(r'\d+', codigo)
            
            # Verifica se foi encontrado algum número
            if numeros:
                # Pega o primeiro número encontrado na lista
                codigo = numeros[0]
                
                # Verifica se o código extraído está na lista de códigos e não foi adicionado ainda
                if any(int(codigo) == item[0] for item in listCodigoQtd) and codigo not in added_codes:
                    file.write(f"    {codigo} -- {i}\n")
                    added_codes.add(codigo)  # Adiciona o código ao conjunto de códigos já adicionados
                    i += 1

    # Caso nenhum código tenha sido registrado, deleta o arquivo
    if i == 1:
        os.remove(arquivo_inativados)
# Out:
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
# Aviso: 'i = 1
# with open(arquivo_inativados, "w") as file:
#     file.write(f"Codigos da unidade {Unidade}\n")
#     file.write(f"Codigos do local {Dispensario}\n\n")
#     file.write("Codigos:\n\n")
#
#     for codigo in inativados:
#         try:
#             # Tente extrair o número antes do " - " e converta para inteiro
#             codigo_num = int(codigo.split(" - ")[0])
#
#             # Verifique se o código existe na lista listCodigoQtd
#             if any(codigo_num == item[0] for item in listCodigoQtd):
#                 file.write(f"    {codigo_num} -- {i}\n")
#                 i += 1
#         except ValueError:
#             # Caso ocorra erro na conversão, ignore esse item e continue
#             print(f"Aviso: '{codigo}' não é um número válido e foi ignorado.")
#             continue
#
# # Remova o arquivo se nenhum código válido for processado
# if i == 1:
#     os.remove(arquivo_inativados)
# ' não é um número válido e foi ignorado.
