# %%
import pyautogui as pa
import keyboard
import mouse
import time

# Lista para armazenar as ações
actions = []
timestamps = []  # Lista para armazenar os timestamps das ações

# Tempo inicial da gravação
start_time = time.time()

def record_mouse_action(event):
    """
    Registra apenas cliques do mouse.
    """
    if isinstance(event, mouse.ButtonEvent) and event.event_type == 'down':
        # Obtém a posição atual do mouse no momento do clique
        x, y = pa.position()
        current_time = time.time()
        timestamps.append(current_time)  # Salva o timestamp
        actions.append(f"pa.click({x}, {y})  # Mouse click at ({x}, {y})")

def record_keyboard_action(event):
    """
    Registra ações do teclado.
    """
    if event.event_type == 'down':  # Captura apenas pressionamentos
        current_time = time.time()
        timestamps.append(current_time)  # Salva o timestamp
        if event.name == 'esc':  # Finaliza a gravação ao pressionar "esc"
            return True
        if len(event.name) == 1:  # Caracteres de escrita
            actions.append(f"pa.write('{event.name}')  # Type: {event.name}")
        else:  # Atalhos ou teclas especiais
            actions.append(f"pa.hotkey('{event.name}')  # Hotkey: {event.name}")
    return False

try:
    print("Iniciando gravação... Pressione ESC para parar.")

    # Inicia os listeners para mouse e teclado
    mouse.hook(record_mouse_action)
    keyboard.hook(record_keyboard_action)

    # Espera até que ESC seja pressionado
    keyboard.wait('esc')

finally:
    # Finaliza a gravação
    mouse.unhook_all()
    keyboard.unhook_all()

    # Gera o código PyAutoGUI
    print("\nAções gravadas:")
    previous_time = start_time
    for i, action in enumerate(actions):
        # Calcula o intervalo de tempo desde a última ação
        delay = timestamps[i] - previous_time
        print(f"time.sleep({delay:.2f})")  # Adiciona o time.sleep ao terminal
        print(action)
        previous_time = timestamps[i]

    # Salva em um arquivo para reutilização
    with open("macro.py", "w") as file:
        file.write("import pyautogui as pa\n")
        file.write("import time\n\n")
        file.write("def play_macro():\n")
        previous_time = start_time
        for i, action in enumerate(actions):
            delay = timestamps[i] - previous_time
            file.write(f"    time.sleep({delay:.2f})\n")
            file.write(f"    {action}\n")
            previous_time = timestamps[i]
        file.write("\nif __name__ == '__main__':\n")
        file.write("    play_macro()\n")

    print("\nAs ações foram salvas no arquivo 'macro.py'.")
# Out:
# Iniciando gravação... Pressione ESC para parar.
#
# Ações gravadas:
# time.sleep(2.89)
# pa.click(82, 143)  # Mouse click at (82, 143)
# time.sleep(1.01)
# pa.click(95, 204)  # Mouse click at (95, 204)
# time.sleep(2.29)
# pa.click(1159, 204)  # Mouse click at (1159, 204)
# time.sleep(1.37)
# pa.click(1163, 393)  # Mouse click at (1163, 393)
# time.sleep(2.85)
# pa.click(1000, 409)  # Mouse click at (1000, 409)
# time.sleep(1.83)
# pa.click(476, 259)  # Mouse click at (476, 259)
# time.sleep(1.57)
# pa.click(542, 382)  # Mouse click at (542, 382)
# time.sleep(1.30)
# pa.click(242, 307)  # Mouse click at (242, 307)
# time.sleep(2.05)
# pa.write('s')  # Type: s
# time.sleep(0.58)
# pa.write('i')  # Type: i
# time.sleep(0.50)
# pa.write('n')  # Type: n
# time.sleep(0.13)
# pa.write('n')  # Type: n
# time.sleep(0.18)
# pa.write('c')  # Type: c
# time.sleep(0.79)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.77)
# pa.write('s')  # Type: s
# time.sleep(2.76)
# pa.click(193, 333)  # Mouse click at (193, 333)
# time.sleep(1.15)
# pa.click(135, 427)  # Mouse click at (135, 427)
# time.sleep(1.62)
# pa.write('s')  # Type: s
# time.sleep(0.61)
# pa.write('i')  # Type: i
# time.sleep(0.60)
# pa.write('n')  # Type: n
# time.sleep(0.19)
# pa.write('n')  # Type: n
# time.sleep(0.34)
# pa.write('c')  # Type: c
# time.sleep(0.36)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.15)
# pa.write('s')  # Type: s
# time.sleep(1.87)
# pa.click(136, 485)  # Mouse click at (136, 485)
# time.sleep(0.89)
# pa.click(134, 503)  # Mouse click at (134, 503)
# time.sleep(2.00)
# pa.click(140, 561)  # Mouse click at (140, 561)
# time.sleep(1.78)
# pa.click(129, 584)  # Mouse click at (129, 584)
# time.sleep(2.10)
# pa.click(164, 423)  # Mouse click at (164, 423)
# time.sleep(1.42)
# pa.click(149, 676)  # Mouse click at (149, 676)
# time.sleep(1.31)
# pa.write('g')  # Type: g
# time.sleep(0.12)
# pa.write('e')  # Type: e
# time.sleep(0.12)
# pa.write('r')  # Type: r
# time.sleep(2.46)
# pa.click(151, 652)  # Mouse click at (151, 652)
# time.sleep(4.06)
# pa.click(1178, 597)  # Mouse click at (1178, 597)
# time.sleep(1.05)
# pa.write('0')  # Type: 0
# time.sleep(0.15)
# pa.write('0')  # Type: 0
# time.sleep(0.10)
# pa.write('3')  # Type: 3
# time.sleep(0.12)
# pa.write('0')  # Type: 0
# time.sleep(2.76)
# pa.click(354, 683)  # Mouse click at (354, 683)
# time.sleep(1.37)
# pa.click(341, 681)  # Mouse click at (341, 681)
# time.sleep(2.71)
# pa.click(164, 337)  # Mouse click at (164, 337)
# time.sleep(1.87)
# pa.click(298, 659)  # Mouse click at (298, 659)
# time.sleep(2.46)
# pa.click(167, 560)  # Mouse click at (167, 560)
# time.sleep(3.05)
# pa.click(604, 350)  # Mouse click at (604, 350)
# time.sleep(4.41)
# pa.hotkey('caps lock')  # Hotkey: caps lock
# time.sleep(0.20)
# pa.write('B')  # Type: B
# time.sleep(0.17)
# pa.hotkey('caps lock')  # Hotkey: caps lock
# time.sleep(0.18)
# pa.write('o')  # Type: o
# time.sleep(0.21)
# pa.write('m')  # Type: m
# time.sleep(0.15)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.13)
# pa.write('d')  # Type: d
# time.sleep(0.19)
# pa.write('i')  # Type: i
# time.sleep(0.07)
# pa.write('a')  # Type: a
# time.sleep(0.10)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.58)
# pa.hotkey('caps lock')  # Hotkey: caps lock
# time.sleep(0.24)
# pa.write('S')  # Type: S
# time.sleep(0.11)
# pa.hotkey('caps lock')  # Hotkey: caps lock
# time.sleep(0.19)
# pa.write('e')  # Type: e
# time.sleep(0.21)
# pa.write('n')  # Type: n
# time.sleep(0.16)
# pa.write('h')  # Type: h
# time.sleep(0.05)
# pa.write('a')  # Type: a
# time.sleep(0.20)
# pa.write('s')  # Type: s
# time.sleep(0.10)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.83)
# pa.write('v')  # Type: v
# time.sleep(0.13)
# pa.write('e')  # Type: e
# time.sleep(0.15)
# pa.write('r')  # Type: r
# time.sleep(0.23)
# pa.write('i')  # Type: i
# time.sleep(0.13)
# pa.write('f')  # Type: f
# time.sleep(0.56)
# pa.write('i')  # Type: i
# time.sleep(0.41)
# pa.write('c')  # Type: c
# time.sleep(0.22)
# pa.write('a')  # Type: a
# time.sleep(0.12)
# pa.write('d')  # Type: d
# time.sleep(0.13)
# pa.write('a')  # Type: a
# time.sleep(0.19)
# pa.write('s')  # Type: s
# time.sleep(1.25)
# pa.write('.')  # Type: .
#
# As ações foram salvas no arquivo 'macro.py'.
