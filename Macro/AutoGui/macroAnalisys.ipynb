# %%
import pyautogui as pa
import keyboard
import mouse
import time

# Lista para armazenar as ações
actions = []
timestamps = []  # Lista para armazenar os timestamps das ações

# Tempo inicial da gravação
start_time = time.time()

def record_mouse_action(event):
    """
    Registra apenas cliques do mouse.
    """
    if isinstance(event, mouse.ButtonEvent) and event.event_type == 'down':
        # Obtém a posição atual do mouse no momento do clique
        x, y = pa.position()
        current_time = time.time()
        timestamps.append(current_time)  # Salva o timestamp
        actions.append(f"pa.click({x}, {y})  # Mouse click at ({x}, {y})")

def record_keyboard_action(event):
    """
    Registra ações do teclado.
    """
    if event.event_type == 'down':  # Captura apenas pressionamentos
        current_time = time.time()
        timestamps.append(current_time)  # Salva o timestamp
        if event.name == 'esc':  # Finaliza a gravação ao pressionar "esc"
            return True
        if len(event.name) == 1:  # Caracteres de escrita
            actions.append(f"pa.write('{event.name}')  # Type: {event.name}")
        else:  # Atalhos ou teclas especiais
            actions.append(f"pa.hotkey('{event.name}')  # Hotkey: {event.name}")
    return False

try:
    print("Iniciando gravação... Pressione ESC para parar.")

    # Inicia os listeners para mouse e teclado
    mouse.hook(record_mouse_action)
    keyboard.hook(record_keyboard_action)

    # Espera até que ESC seja pressionado
    keyboard.wait('esc')

finally:
    # Finaliza a gravação
    mouse.unhook_all()
    keyboard.unhook_all()

    # Gera o código PyAutoGUI
    print("\nAções gravadas:")
    previous_time = start_time
    for i, action in enumerate(actions):
        # Calcula o intervalo de tempo desde a última ação
        delay = timestamps[i] - previous_time
        print(f"time.sleep({delay:.2f})")  # Adiciona o time.sleep ao terminal
        print(action)
        previous_time = timestamps[i]

    # Salva em um arquivo para reutilização
    with open("macro.py", "w") as file:
        file.write("import pyautogui as pa\n")
        file.write("import time\n\n")
        file.write("def play_macro():\n")
        previous_time = start_time
        for i, action in enumerate(actions):
            delay = timestamps[i] - previous_time
            file.write(f"    time.sleep({delay:.2f})\n")
            file.write(f"    {action}\n")
            previous_time = timestamps[i]
        file.write("\nif __name__ == '__main__':\n")
        file.write("    play_macro()\n")

    print("\nAs ações foram salvas no arquivo 'macro.py'.")
# Out:
# Iniciando gravação... Pressione ESC para parar.
#
# Ações gravadas:
# time.sleep(2.52)
# pa.click(78, 137)  # Mouse click at (78, 137)
# time.sleep(1.00)
# pa.click(114, 196)  # Mouse click at (114, 196)
# time.sleep(2.24)
# pa.click(931, 194)  # Mouse click at (931, 194)
# time.sleep(1.73)
# pa.click(1160, 262)  # Mouse click at (1160, 262)
# time.sleep(1.56)
# pa.click(1087, 411)  # Mouse click at (1087, 411)
# time.sleep(2.66)
# pa.click(564, 263)  # Mouse click at (564, 263)
# time.sleep(1.94)
# pa.hotkey('left windows')  # Hotkey: left windows
# time.sleep(0.12)
# pa.write('v')  # Type: v
# time.sleep(2.20)
# pa.click(562, 412)  # Mouse click at (562, 412)
# time.sleep(0.10)
# pa.hotkey('left ctrl')  # Hotkey: left ctrl
# time.sleep(0.04)
# pa.write('v')  # Type: v
# time.sleep(0.76)
# pa.click(562, 343)  # Mouse click at (562, 343)
# time.sleep(0.86)
# pa.hotkey('left windows')  # Hotkey: left windows
# time.sleep(0.15)
# pa.write('v')  # Type: v
# time.sleep(1.21)
# pa.click(541, 429)  # Mouse click at (541, 429)
# time.sleep(0.10)
# pa.hotkey('left ctrl')  # Hotkey: left ctrl
# time.sleep(0.04)
# pa.write('v')  # Type: v
# time.sleep(1.29)
# pa.click(246, 316)  # Mouse click at (246, 316)
# time.sleep(2.19)
# pa.write('s')  # Type: s
# time.sleep(0.54)
# pa.write('i')  # Type: i
# time.sleep(0.23)
# pa.write('n')  # Type: n
# time.sleep(0.16)
# pa.write('n')  # Type: n
# time.sleep(0.16)
# pa.write('c')  # Type: c
# time.sleep(0.12)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.21)
# pa.write('s')  # Type: s
# time.sleep(1.86)
# pa.click(220, 353)  # Mouse click at (220, 353)
# time.sleep(1.19)
# pa.click(155, 432)  # Mouse click at (155, 432)
# time.sleep(1.21)
# pa.write('s')  # Type: s
# time.sleep(0.16)
# pa.write('i')  # Type: i
# time.sleep(0.27)
# pa.write('n')  # Type: n
# time.sleep(0.15)
# pa.write('n')  # Type: n
# time.sleep(0.67)
# pa.write('c')  # Type: c
# time.sleep(0.27)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.24)
# pa.write('s')  # Type: s
# time.sleep(1.77)
# pa.click(143, 479)  # Mouse click at (143, 479)
# time.sleep(1.22)
# pa.click(151, 410)  # Mouse click at (151, 410)
# time.sleep(1.58)
# pa.click(137, 466)  # Mouse click at (137, 466)
# time.sleep(1.08)
# pa.click(153, 484)  # Mouse click at (153, 484)
# time.sleep(1.96)
# pa.click(134, 574)  # Mouse click at (134, 574)
# time.sleep(1.37)
# pa.click(174, 586)  # Mouse click at (174, 586)
# time.sleep(1.63)
# pa.write('g')  # Type: g
# time.sleep(0.19)
# pa.write('e')  # Type: e
# time.sleep(0.19)
# pa.write('r')  # Type: r
# time.sleep(2.13)
# pa.click(111, 554)  # Mouse click at (111, 554)
# time.sleep(2.29)
# pa.click(1185, 598)  # Mouse click at (1185, 598)
# time.sleep(1.00)
# pa.write('0')  # Type: 0
# time.sleep(0.16)
# pa.write('0')  # Type: 0
# time.sleep(1.62)
# pa.write('3')  # Type: 3
# time.sleep(0.26)
# pa.write('0')  # Type: 0
# time.sleep(1.41)
# pa.click(1043, 542)  # Mouse click at (1043, 542)
# time.sleep(1.84)
# pa.click(1256, 423)  # Mouse click at (1256, 423)
# time.sleep(6.07)
# pa.click(340, 642)  # Mouse click at (340, 642)
# time.sleep(3.32)
# pa.click(195, 445)  # Mouse click at (195, 445)
# time.sleep(2.05)
# pa.click(161, 331)  # Mouse click at (161, 331)
# time.sleep(3.99)
# pa.click(1158, 728)  # Mouse click at (1158, 728)
# time.sleep(1.57)
# pa.click(911, 457)  # Mouse click at (911, 457)
# time.sleep(1.65)
# pa.click(85, 146)  # Mouse click at (85, 146)
# time.sleep(0.88)
# pa.click(109, 187)  # Mouse click at (109, 187)
# time.sleep(2.00)
# pa.click(445, 270)  # Mouse click at (445, 270)
# time.sleep(1.92)
# pa.hotkey('left windows')  # Hotkey: left windows
# time.sleep(0.13)
# pa.write('v')  # Type: v
# time.sleep(3.10)
# pa.click(521, 577)  # Mouse click at (521, 577)
# time.sleep(0.11)
# pa.hotkey('left ctrl')  # Hotkey: left ctrl
# time.sleep(0.04)
# pa.write('v')  # Type: v
# time.sleep(0.84)
# pa.click(568, 391)  # Mouse click at (568, 391)
# time.sleep(1.02)
# pa.hotkey('left windows')  # Hotkey: left windows
# time.sleep(0.21)
# pa.write('v')  # Type: v
# time.sleep(2.26)
# pa.click(546, 593)  # Mouse click at (546, 593)
# time.sleep(0.09)
# pa.hotkey('left ctrl')  # Hotkey: left ctrl
# time.sleep(0.04)
# pa.write('v')  # Type: v
# time.sleep(1.74)
# pa.click(1119, 208)  # Mouse click at (1119, 208)
# time.sleep(1.11)
# pa.click(1157, 259)  # Mouse click at (1157, 259)
# time.sleep(0.99)
# pa.click(1100, 400)  # Mouse click at (1100, 400)
# time.sleep(1.69)
# pa.click(1173, 598)  # Mouse click at (1173, 598)
# time.sleep(1.09)
# pa.write('0')  # Type: 0
# time.sleep(0.14)
# pa.write('0')  # Type: 0
# time.sleep(1.11)
# pa.write('3')  # Type: 3
# time.sleep(0.69)
# pa.write('0')  # Type: 0
# time.sleep(2.18)
# pa.click(268, 314)  # Mouse click at (268, 314)
# time.sleep(1.66)
# pa.write('s')  # Type: s
# time.sleep(0.23)
# pa.write('i')  # Type: i
# time.sleep(0.24)
# pa.write('n')  # Type: n
# time.sleep(0.15)
# pa.write('n')  # Type: n
# time.sleep(0.18)
# pa.write('c')  # Type: c
# time.sleep(0.23)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.27)
# pa.write('s')  # Type: s
# time.sleep(1.67)
# pa.click(240, 329)  # Mouse click at (240, 329)
# time.sleep(1.58)
# pa.click(168, 440)  # Mouse click at (168, 440)
# time.sleep(0.57)
# pa.write('s')  # Type: s
# time.sleep(0.69)
# pa.write('i')  # Type: i
# time.sleep(0.46)
# pa.write('n')  # Type: n
# time.sleep(0.15)
# pa.write('n')  # Type: n
# time.sleep(0.24)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.58)
# pa.hotkey('backspace')  # Hotkey: backspace
# time.sleep(0.18)
# pa.write('c')  # Type: c
# time.sleep(0.42)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.14)
# pa.write('s')  # Type: s
# time.sleep(1.36)
# pa.click(161, 491)  # Mouse click at (161, 491)
# time.sleep(1.24)
# pa.click(195, 503)  # Mouse click at (195, 503)
# time.sleep(1.72)
# pa.click(144, 553)  # Mouse click at (144, 553)
# time.sleep(1.12)
# pa.click(131, 578)  # Mouse click at (131, 578)
# time.sleep(1.84)
# pa.click(188, 421)  # Mouse click at (188, 421)
# time.sleep(1.44)
# pa.click(113, 684)  # Mouse click at (113, 684)
# time.sleep(1.09)
# pa.write('g')  # Type: g
# time.sleep(0.22)
# pa.write('e')  # Type: e
# time.sleep(0.05)
# pa.write('r')  # Type: r
# time.sleep(1.57)
# pa.click(122, 645)  # Mouse click at (122, 645)
# time.sleep(1.83)
# pa.click(343, 640)  # Mouse click at (343, 640)
# time.sleep(3.90)
# pa.click(135, 314)  # Mouse click at (135, 314)
# time.sleep(1.81)
# pa.click(150, 549)  # Mouse click at (150, 549)
# time.sleep(2.87)
# pa.click(1195, 732)  # Mouse click at (1195, 732)
# time.sleep(1.95)
# pa.click(893, 441)  # Mouse click at (893, 441)
# time.sleep(0.91)
# pa.click(85, 146)  # Mouse click at (85, 146)
# time.sleep(0.88)
# pa.click(179, 203)  # Mouse click at (179, 203)
# time.sleep(1.58)
# pa.click(548, 272)  # Mouse click at (548, 272)
# time.sleep(1.80)
# pa.hotkey('left windows')  # Hotkey: left windows
# time.sleep(0.14)
# pa.write('v')  # Type: v
# time.sleep(4.37)
# pa.click(493, 537)  # Mouse click at (493, 537)
# time.sleep(0.07)
# pa.hotkey('left ctrl')  # Hotkey: left ctrl
# time.sleep(0.04)
# pa.write('v')  # Type: v
# time.sleep(0.74)
# pa.click(554, 387)  # Mouse click at (554, 387)
# time.sleep(1.27)
# pa.hotkey('left windows')  # Hotkey: left windows
# time.sleep(0.21)
# pa.write('v')  # Type: v
# time.sleep(1.54)
# pa.click(513, 741)  # Mouse click at (513, 741)
# time.sleep(0.10)
# pa.hotkey('left ctrl')  # Hotkey: left ctrl
# time.sleep(0.03)
# pa.write('v')  # Type: v
# time.sleep(2.35)
# pa.click(1187, 603)  # Mouse click at (1187, 603)
# time.sleep(0.92)
# pa.write('0')  # Type: 0
# time.sleep(0.08)
# pa.write('0')  # Type: 0
# time.sleep(0.39)
# pa.hotkey('right shift')  # Hotkey: right shift
# time.sleep(0.19)
# pa.write(':')  # Type: :
# time.sleep(0.62)
# pa.write('3')  # Type: 3
# time.sleep(0.24)
# pa.write('0')  # Type: 0
# time.sleep(1.27)
# pa.click(1019, 189)  # Mouse click at (1019, 189)
# time.sleep(1.56)
# pa.click(1161, 277)  # Mouse click at (1161, 277)
# time.sleep(2.05)
# pa.click(260, 319)  # Mouse click at (260, 319)
# time.sleep(1.56)
# pa.write('s')  # Type: s
# time.sleep(0.16)
# pa.write('i')  # Type: i
# time.sleep(0.24)
# pa.write('n')  # Type: n
# time.sleep(0.18)
# pa.write('n')  # Type: n
# time.sleep(0.15)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.15)
# pa.write('c')  # Type: c
# time.sleep(0.15)
# pa.write('s')  # Type: s
# time.sleep(0.57)
# pa.hotkey('backspace')  # Hotkey: backspace
# time.sleep(0.18)
# pa.hotkey('backspace')  # Hotkey: backspace
# time.sleep(0.15)
# pa.hotkey('backspace')  # Hotkey: backspace
# time.sleep(0.15)
# pa.write('c')  # Type: c
# time.sleep(0.21)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.14)
# pa.write('s')  # Type: s
# time.sleep(1.61)
# pa.click(206, 350)  # Mouse click at (206, 350)
# time.sleep(1.14)
# pa.click(194, 428)  # Mouse click at (194, 428)
# time.sleep(0.94)
# pa.write('s')  # Type: s
# time.sleep(0.20)
# pa.write('i')  # Type: i
# time.sleep(0.23)
# pa.write('n')  # Type: n
# time.sleep(0.15)
# pa.write('n')  # Type: n
# time.sleep(0.39)
# pa.write('c')  # Type: c
# time.sleep(0.24)
# pa.hotkey('space')  # Hotkey: space
# time.sleep(0.15)
# pa.write('s')  # Type: s
# time.sleep(1.29)
# pa.click(141, 479)  # Mouse click at (141, 479)
# time.sleep(0.97)
# pa.click(146, 504)  # Mouse click at (146, 504)
# time.sleep(1.53)
# pa.click(137, 557)  # Mouse click at (137, 557)
# time.sleep(0.91)
# pa.click(133, 592)  # Mouse click at (133, 592)
# time.sleep(1.93)
# pa.click(175, 439)  # Mouse click at (175, 439)
# time.sleep(1.07)
# pa.click(168, 676)  # Mouse click at (168, 676)
# time.sleep(1.68)
# pa.write('g')  # Type: g
# time.sleep(0.10)
# pa.write('e')  # Type: e
# time.sleep(0.26)
# pa.write('r')  # Type: r
# time.sleep(1.63)
# pa.click(182, 654)  # Mouse click at (182, 654)
# time.sleep(3.88)
# pa.click(282, 365)  # Mouse click at (282, 365)
# time.sleep(1.83)
# pa.click(163, 599)  # Mouse click at (163, 599)
# time.sleep(2.30)
# pa.click(1163, 744)  # Mouse click at (1163, 744)
# time.sleep(2.18)
# pa.click(893, 456)  # Mouse click at (893, 456)
#
# As ações foram salvas no arquivo 'macro.py'.
