# %%
import pyautogui as pa
import keyboard
import mouse
import time

# Lista para armazenar as ações
actions = []
timestamps = []  # Lista para armazenar os timestamps das ações

# Tempo inicial da gravação
start_time = time.time()

def record_mouse_action(event):
    """
    Registra apenas cliques do mouse.
    """
    if isinstance(event, mouse.ButtonEvent) and event.event_type == 'down':
        # Obtém a posição atual do mouse no momento do clique
        x, y = pa.position()
        current_time = time.time()
        timestamps.append(current_time)  # Salva o timestamp
        actions.append(f"pa.click({x}, {y})  # Mouse click at ({x}, {y})")

def record_keyboard_action(event):
    """
    Registra ações do teclado.
    """
    if event.event_type == 'down':  # Captura apenas pressionamentos
        current_time = time.time()
        timestamps.append(current_time)  # Salva o timestamp
        if event.name == 'esc':  # Finaliza a gravação ao pressionar "esc"
            return True
        if len(event.name) == 1:  # Caracteres de escrita
            actions.append(f"pa.write('{event.name}')  # Type: {event.name}")
        else:  # Atalhos ou teclas especiais
            actions.append(f"pa.hotkey('{event.name}')  # Hotkey: {event.name}")
    return False

try:
    print("Iniciando gravação... Pressione ESC para parar.")

    # Inicia os listeners para mouse e teclado
    mouse.hook(record_mouse_action)
    keyboard.hook(record_keyboard_action)

    # Espera até que ESC seja pressionado
    keyboard.wait('esc')

finally:
    # Finaliza a gravação
    mouse.unhook_all()
    keyboard.unhook_all()

    # Gera o código PyAutoGUI
    print("\nAções gravadas:")
    previous_time = start_time
    for i, action in enumerate(actions):
        # Calcula o intervalo de tempo desde a última ação
        delay = timestamps[i] - previous_time
        print(f"time.sleep({delay:.2f})")  # Adiciona o time.sleep ao terminal
        print(action)
        previous_time = timestamps[i]

    # Salva em um arquivo para reutilização
    with open("macro.py", "w") as file:
        file.write("import pyautogui as pa\n")
        file.write("import time\n\n")
        file.write("def play_macro():\n")
        previous_time = start_time
        for i, action in enumerate(actions):
            delay = timestamps[i] - previous_time
            file.write(f"    time.sleep({delay:.2f})\n")
            file.write(f"    {action}\n")
            previous_time = timestamps[i]
        file.write("\nif __name__ == '__main__':\n")
        file.write("    play_macro()\n")

    print("\nAs ações foram salvas no arquivo 'macro.py'.")
# Out:
# Iniciando gravação... Pressione ESC para parar.
#
# Ações gravadas:
# time.sleep(2.39)
# pa.mouseDown(-1769, -124)  # Mouse down at (-1769, -124)
# time.sleep(0.04)
# pa.moveTo(-1771, -124)  # Mouse move during drag
# time.sleep(0.06)
# pa.mouseUp(-1771, -124)  # Mouse up at (-1771, -124)
# time.sleep(0.30)
# pa.moveTo(-1771, -124)  # Mouse move to (-1771, -124)
# time.sleep(0.01)
# pa.moveTo(-1771, -120)  # Mouse move to (-1771, -120)
# time.sleep(0.01)
# pa.moveTo(-1770, -113)  # Mouse move to (-1770, -113)
# time.sleep(0.01)
# pa.moveTo(-1767, -100)  # Mouse move to (-1767, -100)
# time.sleep(0.01)
# pa.moveTo(-1764, -86)  # Mouse move to (-1764, -86)
# time.sleep(0.01)
# pa.moveTo(-1761, -72)  # Mouse move to (-1761, -72)
# time.sleep(0.01)
# pa.moveTo(-1747, -47)  # Mouse move to (-1747, -47)
# time.sleep(0.01)
# pa.moveTo(-1735, -20)  # Mouse move to (-1735, -20)
# time.sleep(0.01)
# pa.moveTo(-1716, 16)  # Mouse move to (-1716, 16)
# time.sleep(0.02)
# pa.moveTo(-1695, 52)  # Mouse move to (-1695, 52)
# time.sleep(0.00)
# pa.moveTo(-1666, 93)  # Mouse move to (-1666, 93)
# time.sleep(0.00)
# pa.moveTo(-1636, 145)  # Mouse move to (-1636, 145)
# time.sleep(0.01)
# pa.moveTo(-1554, 256)  # Mouse move to (-1554, 256)
# time.sleep(0.00)
# pa.moveTo(-1554, 256)  # Mouse move to (-1554, 256)
# time.sleep(0.01)
# pa.moveTo(-1522, 301)  # Mouse move to (-1522, 301)
# time.sleep(0.03)
# pa.moveTo(-1469, 378)  # Mouse move to (-1469, 378)
# time.sleep(0.00)
# pa.moveTo(-1418, 452)  # Mouse move to (-1418, 452)
# time.sleep(0.01)
# pa.moveTo(-1418, 452)  # Mouse move to (-1418, 452)
# time.sleep(0.01)
# pa.moveTo(-1380, 509)  # Mouse move to (-1380, 509)
# time.sleep(0.01)
# pa.moveTo(-1380, 509)  # Mouse move to (-1380, 509)
# time.sleep(0.01)
# pa.moveTo(-1335, 578)  # Mouse move to (-1335, 578)
# time.sleep(0.01)
# pa.moveTo(-1335, 578)  # Mouse move to (-1335, 578)
# time.sleep(0.01)
# pa.moveTo(-1319, 600)  # Mouse move to (-1319, 600)
# time.sleep(0.01)
# pa.moveTo(-1304, 621)  # Mouse move to (-1304, 621)
# time.sleep(0.01)
# pa.moveTo(-1296, 630)  # Mouse move to (-1296, 630)
# time.sleep(0.01)
# pa.moveTo(-1291, 635)  # Mouse move to (-1291, 635)
# time.sleep(0.03)
# pa.moveTo(-1288, 639)  # Mouse move to (-1288, 639)
# time.sleep(0.01)
# pa.moveTo(-1283, 642)  # Mouse move to (-1283, 642)
# time.sleep(0.00)
# pa.moveTo(-1283, 642)  # Mouse move to (-1283, 642)
# time.sleep(0.02)
# pa.moveTo(-1281, 642)  # Mouse move to (-1281, 642)
# time.sleep(0.01)
# pa.moveTo(-1280, 642)  # Mouse move to (-1280, 642)
# time.sleep(0.01)
# pa.moveTo(-1280, 644)  # Mouse move to (-1280, 644)
# time.sleep(0.01)
# pa.moveTo(-1277, 646)  # Mouse move to (-1277, 646)
# time.sleep(0.01)
# pa.moveTo(-1275, 648)  # Mouse move to (-1275, 648)
# time.sleep(0.02)
# pa.moveTo(-1273, 650)  # Mouse move to (-1273, 650)
# time.sleep(0.01)
# pa.moveTo(-1272, 652)  # Mouse move to (-1272, 652)
# time.sleep(0.02)
# pa.moveTo(-1272, 654)  # Mouse move to (-1272, 654)
# time.sleep(0.01)
# pa.moveTo(-1272, 656)  # Mouse move to (-1272, 656)
# time.sleep(0.01)
# pa.moveTo(-1270, 658)  # Mouse move to (-1270, 658)
# time.sleep(0.01)
# pa.moveTo(-1270, 664)  # Mouse move to (-1270, 664)
# time.sleep(0.01)
# pa.moveTo(-1270, 664)  # Mouse move to (-1270, 664)
# time.sleep(0.01)
# pa.moveTo(-1270, 668)  # Mouse move to (-1270, 668)
# time.sleep(0.01)
# pa.moveTo(-1270, 676)  # Mouse move to (-1270, 676)
# time.sleep(0.01)
# pa.moveTo(-1270, 692)  # Mouse move to (-1270, 692)
# time.sleep(0.01)
# pa.moveTo(-1270, 692)  # Mouse move to (-1270, 692)
# time.sleep(0.01)
# pa.moveTo(-1270, 702)  # Mouse move to (-1270, 702)
# time.sleep(0.01)
# pa.moveTo(-1272, 718)  # Mouse move to (-1272, 718)
# time.sleep(0.02)
# pa.moveTo(-1275, 736)  # Mouse move to (-1275, 736)
# time.sleep(0.01)
# pa.moveTo(-1292, 780)  # Mouse move to (-1292, 780)
# time.sleep(0.01)
# pa.moveTo(-1292, 780)  # Mouse move to (-1292, 780)
# time.sleep(0.01)
# pa.moveTo(-1300, 797)  # Mouse move to (-1300, 797)
# time.sleep(0.01)
# pa.moveTo(-1305, 810)  # Mouse move to (-1305, 810)
# time.sleep(0.01)
# pa.moveTo(-1310, 830)  # Mouse move to (-1310, 830)
# time.sleep(0.00)
# pa.moveTo(-1310, 830)  # Mouse move to (-1310, 830)
# time.sleep(0.01)
# pa.moveTo(-1310, 832)  # Mouse move to (-1310, 832)
# time.sleep(0.01)
# pa.moveTo(-1310, 834)  # Mouse move to (-1310, 834)
# time.sleep(0.03)
# pa.moveTo(-1310, 838)  # Mouse move to (-1310, 838)
# time.sleep(0.00)
# pa.moveTo(-1310, 838)  # Mouse move to (-1310, 838)
# time.sleep(0.01)
# pa.moveTo(-1307, 839)  # Mouse move to (-1307, 839)
# time.sleep(0.01)
# pa.moveTo(-1307, 839)  # Mouse move to (-1307, 839)
# time.sleep(0.01)
# pa.moveTo(-1304, 839)  # Mouse move to (-1304, 839)
# time.sleep(0.01)
# pa.moveTo(-1300, 839)  # Mouse move to (-1300, 839)
# time.sleep(0.01)
# pa.moveTo(-1291, 839)  # Mouse move to (-1291, 839)
# time.sleep(0.01)
# pa.moveTo(-1291, 839)  # Mouse move to (-1291, 839)
# time.sleep(0.01)
# pa.moveTo(-1285, 839)  # Mouse move to (-1285, 839)
# time.sleep(0.01)
# pa.moveTo(-1279, 839)  # Mouse move to (-1279, 839)
# time.sleep(0.01)
# pa.moveTo(-1273, 838)  # Mouse move to (-1273, 838)
# time.sleep(0.01)
# pa.moveTo(-1273, 838)  # Mouse move to (-1273, 838)
# time.sleep(0.01)
# pa.moveTo(-1270, 836)  # Mouse move to (-1270, 836)
# time.sleep(0.01)
# pa.moveTo(-1267, 836)  # Mouse move to (-1267, 836)
# time.sleep(0.01)
# pa.moveTo(-1263, 836)  # Mouse move to (-1263, 836)
# time.sleep(0.01)
# pa.moveTo(-1263, 836)  # Mouse move to (-1263, 836)
# time.sleep(0.01)
# pa.moveTo(-1261, 836)  # Mouse move to (-1261, 836)
# time.sleep(0.01)
# pa.moveTo(-1259, 836)  # Mouse move to (-1259, 836)
# time.sleep(0.01)
# pa.moveTo(-1256, 836)  # Mouse move to (-1256, 836)
# time.sleep(0.01)
# pa.moveTo(-1256, 836)  # Mouse move to (-1256, 836)
# time.sleep(0.01)
# pa.moveTo(-1254, 836)  # Mouse move to (-1254, 836)
# time.sleep(0.01)
# pa.moveTo(-1252, 836)  # Mouse move to (-1252, 836)
# time.sleep(0.01)
# pa.moveTo(-1248, 837)  # Mouse move to (-1248, 837)
# time.sleep(0.01)
# pa.moveTo(-1248, 837)  # Mouse move to (-1248, 837)
# time.sleep(0.01)
# pa.moveTo(-1244, 838)  # Mouse move to (-1244, 838)
# time.sleep(0.01)
# pa.moveTo(-1244, 838)  # Mouse move to (-1244, 838)
# time.sleep(0.01)
# pa.moveTo(-1240, 838)  # Mouse move to (-1240, 838)
# time.sleep(0.00)
# pa.moveTo(-1240, 838)  # Mouse move to (-1240, 838)
# time.sleep(0.01)
# pa.moveTo(-1238, 838)  # Mouse move to (-1238, 838)
# time.sleep(0.01)
# pa.moveTo(-1236, 838)  # Mouse move to (-1236, 838)
# time.sleep(0.01)
# pa.moveTo(-1231, 837)  # Mouse move to (-1231, 837)
# time.sleep(0.00)
# pa.moveTo(-1231, 837)  # Mouse move to (-1231, 837)
# time.sleep(0.01)
# pa.moveTo(-1224, 835)  # Mouse move to (-1224, 835)
# time.sleep(0.02)
# pa.moveTo(-1218, 831)  # Mouse move to (-1218, 831)
# time.sleep(0.00)
# pa.moveTo(-1218, 831)  # Mouse move to (-1218, 831)
# time.sleep(0.01)
# pa.moveTo(-1210, 828)  # Mouse move to (-1210, 828)
# time.sleep(0.00)
# pa.moveTo(-1210, 828)  # Mouse move to (-1210, 828)
# time.sleep(0.01)
# pa.moveTo(-1208, 826)  # Mouse move to (-1208, 826)
# time.sleep(0.00)
# pa.moveTo(-1208, 826)  # Mouse move to (-1208, 826)
# time.sleep(0.01)
# pa.moveTo(-1204, 824)  # Mouse move to (-1204, 824)
# time.sleep(0.02)
# pa.moveTo(-1204, 824)  # Mouse move to (-1204, 824)
# time.sleep(0.03)
# pa.moveTo(-1200, 824)  # Mouse move to (-1200, 824)
# time.sleep(0.01)
# pa.moveTo(-1200, 824)  # Mouse move to (-1200, 824)
# time.sleep(0.01)
# pa.moveTo(-1199, 824)  # Mouse move to (-1199, 824)
# time.sleep(0.01)
# pa.moveTo(-1197, 824)  # Mouse move to (-1197, 824)
# time.sleep(0.01)
# pa.moveTo(-1193, 824)  # Mouse move to (-1193, 824)
# time.sleep(0.01)
# pa.moveTo(-1193, 824)  # Mouse move to (-1193, 824)
# time.sleep(0.01)
# pa.moveTo(-1191, 826)  # Mouse move to (-1191, 826)
# time.sleep(0.01)
# pa.moveTo(-1189, 826)  # Mouse move to (-1189, 826)
# time.sleep(0.02)
# pa.moveTo(-1187, 826)  # Mouse move to (-1187, 826)
# time.sleep(0.07)
# pa.moveTo(-1181, 832)  # Mouse move to (-1181, 832)
# time.sleep(0.02)
# pa.moveTo(-1179, 832)  # Mouse move to (-1179, 832)
# time.sleep(0.02)
# pa.moveTo(-1177, 832)  # Mouse move to (-1177, 832)
# time.sleep(0.01)
# pa.moveTo(-1172, 832)  # Mouse move to (-1172, 832)
# time.sleep(0.01)
# pa.moveTo(-1172, 832)  # Mouse move to (-1172, 832)
# time.sleep(0.01)
# pa.moveTo(-1162, 832)  # Mouse move to (-1162, 832)
# time.sleep(0.01)
# pa.moveTo(-1162, 832)  # Mouse move to (-1162, 832)
# time.sleep(0.01)
# pa.moveTo(-1148, 833)  # Mouse move to (-1148, 833)
# time.sleep(0.00)
# pa.moveTo(-1148, 833)  # Mouse move to (-1148, 833)
# time.sleep(0.01)
# pa.moveTo(-1140, 836)  # Mouse move to (-1140, 836)
# time.sleep(0.01)
# pa.moveTo(-1140, 836)  # Mouse move to (-1140, 836)
# time.sleep(0.01)
# pa.moveTo(-1136, 838)  # Mouse move to (-1136, 838)
# time.sleep(0.10)
# pa.moveTo(-1136, 838)  # Mouse move to (-1136, 838)
# time.sleep(0.02)
# pa.moveTo(-1139, 838)  # Mouse move to (-1139, 838)
# time.sleep(0.02)
# pa.moveTo(-1141, 837)  # Mouse move to (-1141, 837)
# time.sleep(0.01)
# pa.moveTo(-1141, 837)  # Mouse move to (-1141, 837)
# time.sleep(0.01)
# pa.moveTo(-1143, 837)  # Mouse move to (-1143, 837)
# time.sleep(0.01)
# pa.moveTo(-1145, 835)  # Mouse move to (-1145, 835)
# time.sleep(0.01)
# pa.moveTo(-1148, 834)  # Mouse move to (-1148, 834)
# time.sleep(0.01)
# pa.moveTo(-1153, 833)  # Mouse move to (-1153, 833)
# time.sleep(0.01)
# pa.moveTo(-1153, 833)  # Mouse move to (-1153, 833)
# time.sleep(0.02)
# pa.moveTo(-1155, 833)  # Mouse move to (-1155, 833)
# time.sleep(0.01)
# pa.moveTo(-1157, 831)  # Mouse move to (-1157, 831)
# time.sleep(0.02)
# pa.moveTo(-1159, 831)  # Mouse move to (-1159, 831)
# time.sleep(0.25)
# pa.mouseDown(-1161, 831)  # Mouse down at (-1161, 831)
# time.sleep(0.11)
# pa.moveTo(-1161, 831)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1163, 830)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1173, 826)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1173, 826)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1179, 825)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1187, 822)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1196, 818)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1207, 813)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1218, 808)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1228, 804)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1237, 801)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1240, 799)  # Mouse move during drag
# time.sleep(0.16)
# pa.moveTo(-1244, 797)  # Mouse move during drag
# time.sleep(0.10)
# pa.moveTo(-1244, 797)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1246, 795)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1248, 792)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1250, 790)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1251, 789)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1254, 787)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1256, 785)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1257, 784)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1259, 783)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1262, 779)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1264, 777)  # Mouse move during drag
# time.sleep(0.27)
# pa.moveTo(-1268, 778)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1268, 778)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1270, 776)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1270, 776)  # Mouse move during drag
# time.sleep(0.02)
# pa.moveTo(-1272, 773)  # Mouse move during drag
# time.sleep(0.01)
# pa.moveTo(-1274, 770)  # Mouse move during drag
# time.sleep(0.02)
# pa.moveTo(-1276, 769)  # Mouse move during drag
# time.sleep(0.16)
# pa.moveTo(-1276, 767)  # Mouse move during drag
# time.sleep(0.29)
# pa.moveTo(-1276, 767)  # Mouse move during drag
# time.sleep(0.07)
# pa.mouseUp(-1278, 767)  # Mouse up at (-1278, 767)
# time.sleep(0.18)
# pa.moveTo(-1278, 767)  # Mouse move to (-1278, 767)
# time.sleep(0.01)
# pa.moveTo(-1277, 767)  # Mouse move to (-1277, 767)
# time.sleep(0.01)
# pa.moveTo(-1275, 767)  # Mouse move to (-1275, 767)
# time.sleep(0.01)
# pa.moveTo(-1272, 767)  # Mouse move to (-1272, 767)
# time.sleep(0.01)
# pa.moveTo(-1266, 767)  # Mouse move to (-1266, 767)
# time.sleep(0.01)
# pa.moveTo(-1261, 767)  # Mouse move to (-1261, 767)
# time.sleep(0.02)
# pa.moveTo(-1258, 767)  # Mouse move to (-1258, 767)
# time.sleep(0.01)
# pa.moveTo(-1248, 767)  # Mouse move to (-1248, 767)
# time.sleep(0.01)
# pa.moveTo(-1248, 767)  # Mouse move to (-1248, 767)
# time.sleep(0.01)
# pa.moveTo(-1244, 767)  # Mouse move to (-1244, 767)
# time.sleep(0.01)
# pa.moveTo(-1241, 767)  # Mouse move to (-1241, 767)
# time.sleep(0.05)
# pa.moveTo(-1241, 765)  # Mouse move to (-1241, 765)
# time.sleep(0.60)
# pa.hotkey('ctrl')  # Hotkey: ctrl
# time.sleep(0.21)
# pa.write('c')  # Type: c
# time.sleep(0.57)
# pa.moveTo(-1239, 765)  # Mouse move to (-1239, 765)
#
# As ações foram salvas no arquivo 'macro.py'.
